# %%
import matplotlib.pyplot as plt
import numpy as np

from ase.build import bulk
from ase.calculators.emt import EMT
from ase.eos import EquationOfState
from ase.filters import FrechetCellFilter
from ase.io.espresso import write_espresso_in
from ase.optimize import BFGS
from ase.units import kJ
from ase.visualize.plot import plot_atoms

# %%
hamiltonian_unit_cells=np.load("../../examples/w90/mos2/inputs/hamiltonian_unit_cells.npy")
lattice_vectors=np.load("../../examples/w90/mos2/inputs/lattice_vectors.npy")
wannier_centers=np.load("../../examples/w90/mos2/inputs/wannier_centers.npy")

# %%
hamiltonian_unit_cells
# Out:
# array([[[[[-2.124180e+00+0.j, -0.000000e+00+0.j, -0.000000e+00+0.j,
#            ...,  4.658960e-01+0.j,  0.000000e+00+0.j,
#            -7.585670e-01+0.j],
#           [ 0.000000e+00+0.j, -9.387120e-01+0.j,  0.000000e+00+0.j,
#            ...,  0.000000e+00+0.j,  5.581550e-01+0.j,
#             0.000000e+00+0.j],
#           [ 0.000000e+00+0.j,  0.000000e+00+0.j, -9.393140e-01+0.j,
#            ..., -1.048514e+00+0.j,  0.000000e+00+0.j,
#            -1.480711e+00+0.j],
#           ...,
#           [ 4.658960e-01+0.j,  0.000000e+00+0.j, -1.048514e+00+0.j,
#            ..., -3.839946e+00+0.j,  0.000000e+00+0.j,
#             1.614600e-02+0.j],
#           [-0.000000e+00+0.j,  5.581550e-01+0.j,  0.000000e+00+0.j,
#            ...,  0.000000e+00+0.j, -3.604233e+00+0.j,
#             0.000000e+00+0.j],
#           [-7.585670e-01+0.j,  0.000000e+00+0.j, -1.480711e+00+0.j,
#            ...,  1.614600e-02+0.j,  0.000000e+00+0.j,
#            -3.600787e+00+0.j]]],
#
#
# ...
